# %%
import numpy as np

# %%
carga_inicial = 20
factor_suma_carga = 0.25
carga_final = carga_inicial + (18 * factor_suma_carga)

distancia_AD = 1
distancia_AB = 2
distancia_BC = 2
distancia_BE = 1
distancia_AC = 4

angulo_barra_EC = np.arctan(distancia_AD / distancia_BC)
angulo_barra_AE = np.arctan(distancia_AD / distancia_AB)

# %%
rango_cargas = np.arange(carga_inicial, carga_final, factor_suma_carga )
rango_angulos = np.arange(0, 180, 10)

# %%
# EQUILIBRIO EXTERNO

def calcular_reacciones(carga, angulo, distancia_AC):
    angulos_radianes = angulo * np.pi / 180
    Ay = carga * np.cos(angulos_radianes)
    Dx = distancia_AC * carga * np. sin(angulos_radianes)
    Ax = carga * np.sin(angulos_radianes) - Dx
    return Ax, Ay, Dx

# %%
# CALCULO FUERZAS INTERNAS

# NODO C
def calcular_fuerzas_nodo_C(carga, angulo, angulo_barra_EC):
    angulos_radianes = angulo * np.pi / 180
    CE = carga * np. cos(angulos_radianes) /  np. sin(angulo_barra_EC)
    BC = carga * np. sin(angulos_radianes) - CE *  np. cos(angulo_barra_EC)
    return CE, BC

# NODO B 
def calcular_fuerzas_nodo_B(fuerza_BC):
    BA = fuerza_BC
    BE = 0
    return BA, BE 

# NODO E
def calcular_fuerzas_nodo_E(CE, angulo_barra_AE, angulo_barra_EC):
    EA = - CE * np.sin(angulo_barra_EC) / np.sin(angulo_barra_AE)
    ED = - EA * np.cos(angulo_barra_AE) + CE * np.cos(angulo_barra_EC)
    return EA, ED

# NODO D
def calcular_fuerzas_nodo_D(Dx):
    ED = - Dx
    DA = 0
    return ED, DA

# NODO A
def calcular_fuerzas_nodo_A(Ax, Ay, angulo_barra_AE,):
    AE = Ay / np.sin(angulo_barra_AE)
    AB = - Ax - AE * np.cos(angulo_barra_AE)
    return AE, AB

# %%
fuerza_maxima = np.array([0, 0, 0, 0, 0, 0, 0])
for angulo, carga in zip(rango_angulos, rango_cargas):
    Ax, Ay, Dx = calcular_reacciones(carga, angulo, distancia_AC)
    CE, BC = calcular_fuerzas_nodo_C(carga, angulo, angulo_barra_EC)
    BA, BE = calcular_fuerzas_nodo_B(BC)
    EA, ED = calcular_fuerzas_nodo_E(CE, angulo_barra_AE, angulo_barra_EC)
    DE, DA = calcular_fuerzas_nodo_D(Dx)
    AE, AB = calcular_fuerzas_nodo_A(Ax, Ay, angulo_barra_AE,)
    print(f"Reacciones angulo {angulo} grados: ")
    print(Ax, Ay, Dx)
    print("Fuerzas internas:")
    print(BA, EA, DA, BC, BE, CE, ED)
    print(f"{AE} == {EA}, {AB} == {BA}, {DE} == {ED}")
    print()
    fuerza_maxima[0] = BA if np.absolute(BA) > fuerza_maxima[0] else fuerza_maxima[0]
    fuerza_maxima[1] = BC if np.absolute(BC) > fuerza_maxima[1] else fuerza_maxima[1]
    fuerza_maxima[2] = CE if np.absolute(CE) > fuerza_maxima[2] else fuerza_maxima[2]
    fuerza_maxima[3] = ED if np.absolute(ED) > fuerza_maxima[3] else fuerza_maxima[3]
    fuerza_maxima[4] = EA if np.absolute(EA) > fuerza_maxima[4] else fuerza_maxima[4]
    fuerza_maxima[5] = DA if np.absolute(DA) > fuerza_maxima[5] else fuerza_maxima[5]
    fuerza_maxima[6] = BE if np.absolute(BE) > fuerza_maxima[6] else fuerza_maxima[6]
        
print(fuerza_maxima)
# Out:
# Reacciones angulo 0 grados:
# 0.0 20.0 0.0
# Fuerzas internas:
# -40.0 -44.721359549995796 0 -40.0 0 44.721359549995796 80.0
# 44.721359549995796 == -44.721359549995796, -40.0 == -40.0, -0.0 == 80.0
#
# Reacciones angulo 10 grados:
# -10.549126793266018 19.942356998497214 14.065502391021356
# Fuerzas internas:
# -36.368338399239086 -44.592465880208444 0 -36.368338399239086 0 44.592465880208444 79.76942799398886
# 44.592465880208444 == -44.592465880208444, -29.33558720372841 == -36.368338399239086, -14.065502391021356 == 79.76942799398886
#
# Reacciones angulo 20 grados:
# -21.034238814528628 19.263698726111123 28.045651752704835
# Fuerzas internas:
# -31.51598451404604 -43.07493984966057 0 -31.51598451404604 0 43.07493984966057 77.05479490444449
# 43.07493984966057 == -43.07493984966057, -17.493158637693618 == -31.51598451404604, -28.045651752704835 == 77.05479490444449
#
# Reacciones angulo 30 grados:
# -31.124999999999993 17.970027128527104 41.49999999999999
# Fuerzas internas:
# -25.565054257054207 -40.182202216901956 0 -25.565054257054207 0 40.182202216901956 71.88010851410841
# 40.182202216901956 == -40.182202216901956, -4.815054257054214 == -25.565054257054207, -41.49999999999999 == 71.88010851410841
#
# Reacciones angulo 40 grados:
# -40.495619410251976 16.086933305498537 53.9941592136693
# Fuerzas internas:
# -18.67532680757975 -35.97147642060012 0 -18.67532680757975 0 35.97147642060012 64.34773322199415
# 35.97147642060012 == -35.97147642060012, 8.321752799254902 == -18.67532680757975, -53.9941592136693 == 64.34773322199415
#
# Reacciones angulo 50 grados:
# -48.83533324883485 13.659236705838962 65.11377766511313
# Fuerzas internas:
# -11.040028995399641 -30.542981795016217 0 -11.040028995399641 0 30.542981795016217 54.63694682335585
# 30.542981795016217 == -30.542981795016217, 21.516859837156925 == -11.040028995399641, -65.11377766511313 == 54.63694682335585
#
# Reacciones angulo 60 grados:
# -55.85863854409629 10.750000000000002 74.47818472546172
# Fuerzas internas:
# -2.8804538186345745 -24.037730758122745 0 -2.8804538186345745 0 24.037730758122745 43.00000000000001
# 24.037730758122745 == -24.037730758122745, 34.35863854409628 == -2.8804538186345745, -74.47818472546172 == 43.00000000000001
#
# Reacciones angulo 70 grados:
# -61.314943506280514 7.438938117333297 81.75325800837402
# Fuerzas internas:
# 5.56043826742691 -16.63397131077156 0 5.56043826742691 0 16.63397131077156 29.75575246933319
# 16.63397131077156 == -16.63397131077156, 46.43706727161392 == 5.56043826742691, -81.75325800837402 == 29.75575246933319
#
# Reacciones angulo 80 grados:
# -64.99731169880573 3.820259908672469 86.66308226507431
# Fuerzas internas:
# 14.02525074892364 -8.542360847508778 0 14.02525074892364 0 8.542360847508778 15.281039634689874
# 8.542360847508778 == -8.542360847508778, 57.35679188146079 == 14.02525074892364, -86.66308226507431 == 15.281039634689874
#
# Reacciones angulo 90 grados:
# -66.75 1.3624195640514305e-15 89.0
# Fuerzas internas:
# 22.249999999999996 -3.0464627590946276e-15 0 22.249999999999996 0 3.0464627590946276e-15 5.449678256205722e-15
# 3.0464627590946276e-15 == -3.0464627590946276e-15, 66.75 == 22.249999999999996, -89.0 == 5.449678256205722e-15
#
# Reacciones angulo 100 grados:
# -66.47452332832404 -3.9070839975059317 88.63269777109872
# Fuerzas internas:
# 29.972342437786544 8.736505412224883 0 29.972342437786544 0 -8.736505412224883 -15.628335990023729
# -8.736505412224883 == 8.736505412224883, 74.28869132333591 == 29.972342437786544, -88.63269777109872 == -15.628335990023729
#
# Reacciones angulo 110 grados:
# -64.13402136863826 -7.780958260658963 85.51202849151767
# Fuerzas internas:
# 36.93992364419734 17.39875160092197 0 36.93992364419734 0 -17.39875160092197 -31.12383304263585
# -17.39875160092197 == 17.39875160092197, 79.69593788995618 == 36.93992364419734, -85.51202849151767 == -31.12383304263585
#
# Reacciones angulo 120 grados:
# -59.75575286112627 -11.499999999999995 79.67433714816836
# Fuerzas internas:
# 42.91858428704208 25.71478174124757 0 42.91858428704208 0 -25.71478174124757 -45.99999999999998
# -25.71478174124757 == 25.71478174124757, 82.75575286112625 == 42.91858428704208, -79.67433714816836 == -45.99999999999998
#
# Reacciones angulo 130 grados:
# -53.431599907548716 -14.94481192521204 71.24213321006495
# Fuerzas internas:
# 47.70015715294032 33.41761537572363 0 47.70015715294032 0 -33.41761537572363 -59.77924770084817
# -33.41761537572363 == 33.41761537572363, 83.3212237579728 == 47.70015715294032, -71.24213321006495 == -59.77924770084817
#
# Reacciones angulo 140 grados:
# -45.31652648290103 -18.00204441329598 60.42203531053471
# Fuerzas internas:
# 51.10959765422564 40.25379504210013 0 51.10959765422564 0 -40.25379504210013 -72.00817765318392
# -40.25379504210013 == 40.25379504210013, 81.320615309493 == 51.10959765422564, -60.42203531053471 == -72.00817765318392
#
# Reacciones angulo 150 grados:
# -35.62499999999999 -20.56810333988042 47.49999999999999
# Fuerzas internas:
# 53.01120667976084 45.99167723621308 0 53.01120667976084 0 -45.99167723621308 -82.27241335952168
# -45.99167723621308 == 45.99167723621308, 76.76120667976083 == 53.01120667976084, -47.49999999999999 == -82.27241335952168
#
# Reacciones angulo 160 grados:
# -24.62545031944816 -22.5526228988618 32.83393375926421
# Fuerzas internas:
# 53.31372923753965 50.42919787277335 0 53.31372923753965 0 -50.42919787277335 -90.2104915954472
# -50.42919787277335 == 50.42919787277335, 69.73069611717176 == 53.31372923753965, -32.83393375926421 == -90.2104915954472
#
# Reacciones angulo 170 grados:
# -12.632904925269177 -23.881588010546043 16.843873233692236
# Fuerzas internas:
# 51.97414432951514 53.40085420222492 0 51.97414432951514 0 -53.40085420222492 -95.52635204218417
# -53.40085420222492 == 53.40085420222492, 60.396080946361266 == 51.97414432951514, -16.843873233692236 == -95.52635204218417
#
# [ 53  53 -53 -95  53   0   0]

# %%
# MPa 
esfuerzo_admisible = 15
# mm 2
area = 300

# %%
# Kilo Newtons
fuerza_maxima = esfuerzo_admisible * area /1000

# %%
fuerzas_internas = np.array([0, 0, 0, 0, 0, 0, 0])
for angulo, carga in zip(rango_angulos, rango_cargas):
     Ax, Ay, Dx = calcular_reacciones(carga, angulo, distancia_AC)
     CE, BC = calcular_fuerzas_nodo_C(carga, angulo, angulo_barra_EC)
     BA, BE = calcular_fuerzas_nodo_B(BC)
     EA, ED = calcular_fuerzas_nodo_E(CE, angulo_barra_AE, angulo_barra_EC)
     DE, DA = calcular_fuerzas_nodo_D(Dx)
     AE, AB = calcular_fuerzas_nodo_A(Ax, Ay, angulo_barra_AE,)
     fuerzas_internas = np.array([("AB", BA), ("AE", EA), ("AD", DA), ("BC", BC), ("BE", BE), ("CE", CE), ("ED", ED)])
     elementos_que_fallan = np.where(np.absolute(np.array([x[1] for x in fuerzas_internas], dtype=np.float64)) > fuerza_maxima)
     if len(elementos_que_fallan) > 0:
        print(f"La primera falla se presenta bajo la carga de {carga} kN y la direccion de {angulo} grados ")
        for i in elementos_que_fallan[0]:
            fuerza = fuerzas_internas[i][1].astype(float)
            causa_falla = "compresión" if fuerza < 0 else "tracción"
            print(f"El elemento {fuerzas_internas[i][0]} falla bajo la carga {np.absolute(fuerza)} kN a {causa_falla}")
        print()
# Out:
# La primera falla se presenta bajo la carga de 20.0 kN y la direccion de 0 grados
# El elemento AB falla bajo la carga 40.0 kN a compresión
# El elemento AE falla bajo la carga 44.721359549995796 kN a compresión
# El elemento BC falla bajo la carga 40.0 kN a compresión
# El elemento CE falla bajo la carga 44.721359549995796 kN a tracción
# El elemento ED falla bajo la carga 80.0 kN a tracción
#
# La primera falla se presenta bajo la carga de 20.25 kN y la direccion de 10 grados
# El elemento AB falla bajo la carga 36.368338399239086 kN a compresión
# El elemento AE falla bajo la carga 44.592465880208444 kN a compresión
# El elemento BC falla bajo la carga 36.368338399239086 kN a compresión
# El elemento CE falla bajo la carga 44.592465880208444 kN a tracción
# El elemento ED falla bajo la carga 79.76942799398886 kN a tracción
#
# La primera falla se presenta bajo la carga de 20.5 kN y la direccion de 20 grados
# El elemento AB falla bajo la carga 31.51598451404604 kN a compresión
# El elemento AE falla bajo la carga 43.07493984966057 kN a compresión
# El elemento BC falla bajo la carga 31.51598451404604 kN a compresión
# El elemento CE falla bajo la carga 43.07493984966057 kN a tracción
# El elemento ED falla bajo la carga 77.05479490444449 kN a tracción
#
# La primera falla se presenta bajo la carga de 20.75 kN y la direccion de 30 grados
# El elemento AB falla bajo la carga 25.565054257054207 kN a compresión
# El elemento AE falla bajo la carga 40.182202216901956 kN a compresión
# El elemento BC falla bajo la carga 25.565054257054207 kN a compresión
# El elemento CE falla bajo la carga 40.182202216901956 kN a tracción
# El elemento ED falla bajo la carga 71.88010851410841 kN a tracción
#
# La primera falla se presenta bajo la carga de 21.0 kN y la direccion de 40 grados
# El elemento AB falla bajo la carga 18.67532680757975 kN a compresión
# El elemento AE falla bajo la carga 35.97147642060012 kN a compresión
# El elemento BC falla bajo la carga 18.67532680757975 kN a compresión
# El elemento CE falla bajo la carga 35.97147642060012 kN a tracción
# El elemento ED falla bajo la carga 64.34773322199415 kN a tracción
#
# La primera falla se presenta bajo la carga de 21.25 kN y la direccion de 50 grados
# El elemento AB falla bajo la carga 11.040028995399641 kN a compresión
# El elemento AE falla bajo la carga 30.542981795016217 kN a compresión
# El elemento BC falla bajo la carga 11.040028995399641 kN a compresión
# El elemento CE falla bajo la carga 30.542981795016217 kN a tracción
# El elemento ED falla bajo la carga 54.63694682335585 kN a tracción
#
# La primera falla se presenta bajo la carga de 21.5 kN y la direccion de 60 grados
# El elemento AE falla bajo la carga 24.037730758122745 kN a compresión
# El elemento CE falla bajo la carga 24.037730758122745 kN a tracción
# El elemento ED falla bajo la carga 43.00000000000001 kN a tracción
#
# La primera falla se presenta bajo la carga de 21.75 kN y la direccion de 70 grados
# El elemento AB falla bajo la carga 5.56043826742691 kN a tracción
# El elemento AE falla bajo la carga 16.63397131077156 kN a compresión
# El elemento BC falla bajo la carga 5.56043826742691 kN a tracción
# El elemento CE falla bajo la carga 16.63397131077156 kN a tracción
# El elemento ED falla bajo la carga 29.75575246933319 kN a tracción
#
# La primera falla se presenta bajo la carga de 22.0 kN y la direccion de 80 grados
# El elemento AB falla bajo la carga 14.02525074892364 kN a tracción
# El elemento AE falla bajo la carga 8.542360847508778 kN a compresión
# El elemento BC falla bajo la carga 14.02525074892364 kN a tracción
# El elemento CE falla bajo la carga 8.542360847508778 kN a tracción
# El elemento ED falla bajo la carga 15.281039634689874 kN a tracción
#
# La primera falla se presenta bajo la carga de 22.25 kN y la direccion de 90 grados
# El elemento AB falla bajo la carga 22.249999999999996 kN a tracción
# El elemento BC falla bajo la carga 22.249999999999996 kN a tracción
#
# La primera falla se presenta bajo la carga de 22.5 kN y la direccion de 100 grados
# El elemento AB falla bajo la carga 29.972342437786544 kN a tracción
# El elemento AE falla bajo la carga 8.736505412224883 kN a tracción
# El elemento BC falla bajo la carga 29.972342437786544 kN a tracción
# El elemento CE falla bajo la carga 8.736505412224883 kN a compresión
# El elemento ED falla bajo la carga 15.628335990023729 kN a compresión
#
# La primera falla se presenta bajo la carga de 22.75 kN y la direccion de 110 grados
# El elemento AB falla bajo la carga 36.93992364419734 kN a tracción
# El elemento AE falla bajo la carga 17.39875160092197 kN a tracción
# El elemento BC falla bajo la carga 36.93992364419734 kN a tracción
# El elemento CE falla bajo la carga 17.39875160092197 kN a compresión
# El elemento ED falla bajo la carga 31.12383304263585 kN a compresión
#
# La primera falla se presenta bajo la carga de 23.0 kN y la direccion de 120 grados
# El elemento AB falla bajo la carga 42.91858428704208 kN a tracción
# El elemento AE falla bajo la carga 25.71478174124757 kN a tracción
# El elemento BC falla bajo la carga 42.91858428704208 kN a tracción
# El elemento CE falla bajo la carga 25.71478174124757 kN a compresión
# El elemento ED falla bajo la carga 45.99999999999998 kN a compresión
#
# La primera falla se presenta bajo la carga de 23.25 kN y la direccion de 130 grados
# El elemento AB falla bajo la carga 47.70015715294032 kN a tracción
# El elemento AE falla bajo la carga 33.41761537572363 kN a tracción
# El elemento BC falla bajo la carga 47.70015715294032 kN a tracción
# El elemento CE falla bajo la carga 33.41761537572363 kN a compresión
# El elemento ED falla bajo la carga 59.77924770084817 kN a compresión
#
# La primera falla se presenta bajo la carga de 23.5 kN y la direccion de 140 grados
# El elemento AB falla bajo la carga 51.10959765422564 kN a tracción
# El elemento AE falla bajo la carga 40.25379504210013 kN a tracción
# El elemento BC falla bajo la carga 51.10959765422564 kN a tracción
# El elemento CE falla bajo la carga 40.25379504210013 kN a compresión
# El elemento ED falla bajo la carga 72.00817765318392 kN a compresión
#
# La primera falla se presenta bajo la carga de 23.75 kN y la direccion de 150 grados
# El elemento AB falla bajo la carga 53.01120667976084 kN a tracción
# El elemento AE falla bajo la carga 45.99167723621308 kN a tracción
# El elemento BC falla bajo la carga 53.01120667976084 kN a tracción
# El elemento CE falla bajo la carga 45.99167723621308 kN a compresión
# El elemento ED falla bajo la carga 82.27241335952168 kN a compresión
#
# La primera falla se presenta bajo la carga de 24.0 kN y la direccion de 160 grados
# El elemento AB falla bajo la carga 53.31372923753965 kN a tracción
# El elemento AE falla bajo la carga 50.42919787277335 kN a tracción
# El elemento BC falla bajo la carga 53.31372923753965 kN a tracción
# El elemento CE falla bajo la carga 50.42919787277335 kN a compresión
# El elemento ED falla bajo la carga 90.2104915954472 kN a compresión
#
# La primera falla se presenta bajo la carga de 24.25 kN y la direccion de 170 grados
# El elemento AB falla bajo la carga 51.97414432951514 kN a tracción
# El elemento AE falla bajo la carga 53.40085420222492 kN a tracción
# El elemento BC falla bajo la carga 51.97414432951514 kN a tracción
# El elemento CE falla bajo la carga 53.40085420222492 kN a compresión
# El elemento ED falla bajo la carga 95.52635204218417 kN a compresión

# %%
# TERCER PUNTO

L = 2
aumento_distancia = float("0.0" + str(L))
A = 9
B = 2

AB = 92
AB = round(AB / 10) * 10

distancia_AC = 2
distancia_AB = 2

# %%
for angulo, carga in zip(rango_angulos, rango_cargas):
    distancia_AC += aumento_distancia
    distancia_AB += aumento_distancia
    angulo_barra_inclinada_AE = np.arctan(distancia_AD / distancia_AB)
    Ax, Ay, Dx = calcular_reacciones(carga, angulo, distancia_AC)
    CE, BC = calcular_fuerzas_nodo_C(carga, angulo, angulo_barra_EC)
    BA, BE = calcular_fuerzas_nodo_B(BC)
    EA, ED = calcular_fuerzas_nodo_E(CE, angulo_barra_AE, angulo_barra_EC)
    DE, DA = calcular_fuerzas_nodo_D(Dx)
    AE, AB = calcular_fuerzas_nodo_A(Ax, Ay, angulo_barra_AE,)
    fuerzas_internas = [("AB", BA, carga), ("AE", EA, carga), ("AD", DA, carga), ("BC", BC, carga), ("BE", BE, carga), ("CE", CE, carga), ("ED", ED, carga)]
    print(f"Para un aumento de distancia de {distancia_AB - 2} las fuerzas calculadas son:")
    print(fuerzas_internas)
    print()
# Out:
# Para un aumento de distancia de 0.020000000000000018 las fuerzas calculadas son:
# [('AB', -40.0, 20.0), ('AE', -44.721359549995796, 20.0), ('AD', 0, 20.0), ('BC', -40.0, 20.0), ('BE', 0, 20.0), ('CE', 44.721359549995796, 20.0), ('ED', 80.0, 20.0)]
#
# Para un aumento de distancia de 0.040000000000000036 las fuerzas calculadas son:
# [('AB', -36.368338399239086, 20.25), ('AE', -44.592465880208444, 20.25), ('AD', 0, 20.25), ('BC', -36.368338399239086, 20.25), ('BE', 0, 20.25), ('CE', 44.592465880208444, 20.25), ('ED', 79.76942799398886, 20.25)]
#
# Para un aumento de distancia de 0.06000000000000005 las fuerzas calculadas son:
# [('AB', -31.51598451404604, 20.5), ('AE', -43.07493984966057, 20.5), ('AD', 0, 20.5), ('BC', -31.51598451404604, 20.5), ('BE', 0, 20.5), ('CE', 43.07493984966057, 20.5), ('ED', 77.05479490444449, 20.5)]
#
# Para un aumento de distancia de 0.08000000000000007 las fuerzas calculadas son:
# [('AB', -25.565054257054207, 20.75), ('AE', -40.182202216901956, 20.75), ('AD', 0, 20.75), ('BC', -25.565054257054207, 20.75), ('BE', 0, 20.75), ('CE', 40.182202216901956, 20.75), ('ED', 71.88010851410841, 20.75)]
#
# Para un aumento de distancia de 0.10000000000000009 las fuerzas calculadas son:
# [('AB', -18.67532680757975, 21.0), ('AE', -35.97147642060012, 21.0), ('AD', 0, 21.0), ('BC', -18.67532680757975, 21.0), ('BE', 0, 21.0), ('CE', 35.97147642060012, 21.0), ('ED', 64.34773322199415, 21.0)]
#
# Para un aumento de distancia de 0.1200000000000001 las fuerzas calculadas son:
# [('AB', -11.040028995399641, 21.25), ('AE', -30.542981795016217, 21.25), ('AD', 0, 21.25), ('BC', -11.040028995399641, 21.25), ('BE', 0, 21.25), ('CE', 30.542981795016217, 21.25), ('ED', 54.63694682335585, 21.25)]
#
# Para un aumento de distancia de 0.14000000000000012 las fuerzas calculadas son:
# [('AB', -2.8804538186345745, 21.5), ('AE', -24.037730758122745, 21.5), ('AD', 0, 21.5), ('BC', -2.8804538186345745, 21.5), ('BE', 0, 21.5), ('CE', 24.037730758122745, 21.5), ('ED', 43.00000000000001, 21.5)]
#
# Para un aumento de distancia de 0.16000000000000014 las fuerzas calculadas son:
# [('AB', 5.56043826742691, 21.75), ('AE', -16.63397131077156, 21.75), ('AD', 0, 21.75), ('BC', 5.56043826742691, 21.75), ('BE', 0, 21.75), ('CE', 16.63397131077156, 21.75), ('ED', 29.75575246933319, 21.75)]
#
# Para un aumento de distancia de 0.18000000000000016 las fuerzas calculadas son:
# [('AB', 14.02525074892364, 22.0), ('AE', -8.542360847508778, 22.0), ('AD', 0, 22.0), ('BC', 14.02525074892364, 22.0), ('BE', 0, 22.0), ('CE', 8.542360847508778, 22.0), ('ED', 15.281039634689874, 22.0)]
#
# Para un aumento de distancia de 0.20000000000000018 las fuerzas calculadas son:
# [('AB', 22.249999999999996, 22.25), ('AE', -3.0464627590946276e-15, 22.25), ('AD', 0, 22.25), ('BC', 22.249999999999996, 22.25), ('BE', 0, 22.25), ('CE', 3.0464627590946276e-15, 22.25), ('ED', 5.449678256205722e-15, 22.25)]
#
# Para un aumento de distancia de 0.2200000000000002 las fuerzas calculadas son:
# [('AB', 29.972342437786544, 22.5), ('AE', 8.736505412224883, 22.5), ('AD', 0, 22.5), ('BC', 29.972342437786544, 22.5), ('BE', 0, 22.5), ('CE', -8.736505412224883, 22.5), ('ED', -15.628335990023729, 22.5)]
#
# Para un aumento de distancia de 0.2400000000000002 las fuerzas calculadas son:
# [('AB', 36.93992364419734, 22.75), ('AE', 17.39875160092197, 22.75), ('AD', 0, 22.75), ('BC', 36.93992364419734, 22.75), ('BE', 0, 22.75), ('CE', -17.39875160092197, 22.75), ('ED', -31.12383304263585, 22.75)]
#
# Para un aumento de distancia de 0.26000000000000023 las fuerzas calculadas son:
# [('AB', 42.91858428704208, 23.0), ('AE', 25.71478174124757, 23.0), ('AD', 0, 23.0), ('BC', 42.91858428704208, 23.0), ('BE', 0, 23.0), ('CE', -25.71478174124757, 23.0), ('ED', -45.99999999999998, 23.0)]
#
# Para un aumento de distancia de 0.28000000000000025 las fuerzas calculadas son:
# [('AB', 47.70015715294032, 23.25), ('AE', 33.41761537572363, 23.25), ('AD', 0, 23.25), ('BC', 47.70015715294032, 23.25), ('BE', 0, 23.25), ('CE', -33.41761537572363, 23.25), ('ED', -59.77924770084817, 23.25)]
#
# Para un aumento de distancia de 0.30000000000000027 las fuerzas calculadas son:
# [('AB', 51.10959765422564, 23.5), ('AE', 40.25379504210013, 23.5), ('AD', 0, 23.5), ('BC', 51.10959765422564, 23.5), ('BE', 0, 23.5), ('CE', -40.25379504210013, 23.5), ('ED', -72.00817765318392, 23.5)]
#
# Para un aumento de distancia de 0.3200000000000003 las fuerzas calculadas son:
# [('AB', 53.01120667976084, 23.75), ('AE', 45.99167723621308, 23.75), ('AD', 0, 23.75), ('BC', 53.01120667976084, 23.75), ('BE', 0, 23.75), ('CE', -45.99167723621308, 23.75), ('ED', -82.27241335952168, 23.75)]
#
# Para un aumento de distancia de 0.3400000000000003 las fuerzas calculadas son:
# [('AB', 53.31372923753965, 24.0), ('AE', 50.42919787277335, 24.0), ('AD', 0, 24.0), ('BC', 53.31372923753965, 24.0), ('BE', 0, 24.0), ('CE', -50.42919787277335, 24.0), ('ED', -90.2104915954472, 24.0)]
#
# Para un aumento de distancia de 0.3600000000000003 las fuerzas calculadas son:
# [('AB', 51.97414432951514, 24.25), ('AE', 53.40085420222492, 24.25), ('AD', 0, 24.25), ('BC', 51.97414432951514, 24.25), ('BE', 0, 24.25), ('CE', -53.40085420222492, 24.25), ('ED', -95.52635204218417, 24.25)]
