# %% [markdown]
# ##EJERCICIO 2

# %%
import math

def sen(grads):
    return math.sin(math.radians(grads))
def cos(grads):
    return math.cos(math.radians(grads))
def tan(grads):
    return math.tan(math.radians(grads))
import numpy as np
import matplotlib.pyplot as plt

# %%
#Valores a utilizar
#En mm2, MPa, kN
a=1200
esf_ad=21
#Iterar teta
teta=0
teta1=math.degrees(math.atan(1/2))

# %%
#Reacciones y esfuerzos de forma general
p=0.025*teta+20
#p se arregla con un if luego
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)

esfRde=Rde/a*1000
esfRad=Rad/a*1000
esfRae=Rae/a*1000
esfRab=Rab/a*1000
esfRbe=Rbe/a*1000
esfRbc=esfRab
esfRce=Rce/a*1000

# %%
#(punto2)Valor de ángulo y carga cuando ocurre la primera falla
teta=0
p=0.025*teta+20
#p se arregla con un if luego
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)

esfRde=Rde/a*1000
esfRad=Rad/a*1000
esfRae=Rae/a*1000
esfRab=Rab/a*1000
esfRbe=Rbe/a*1000
esfRbc=esfRab
esfRce=Rce/a*1000
esfRde=abs(esfRde)
esfRad=abs(esfRad)
esfRae=abs(esfRae)
esfRab=abs(esfRab)
esfRbe=abs(esfRbe)
esfRbc=abs(esfRbc)
esfRce=abs(esfRce)

while esfRde<esf_ad and esfRad<esf_ad and esfRae<esf_ad and esfRab<esf_ad and esfRbe<esf_ad and esfRbc<esf_ad and esfRce<esf_ad:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    Dx=-4*p*cos(teta)
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rde=Dx
    Rad=0
    Rae=Ay/(sen(teta1))
    Rab=-Rae*cos(teta1)-Ax
    Rbe=0
    Rbc=Rab
    Rce=p*cos(teta)/sen(teta1)
    esfRde=Rde/a*1000
    esfRad=Rad/a*1000
    esfRae=Rae/a*1000
    esfRab=Rab/a*1000
    esfRbe=Rbe/a*1000
    esfRbc=esfRab
    esfRce=Rce/a*1000
print("Ángulo=",teta,"°")
# falla con teta
print("Carga=",p," kN")
# Out:
# Ángulo= 0 °
# Carga= 20.0  kN

# %%
#(punto2)Primera dirección donde todos los elementos soportan la carga(esfuerzos menores al admisible)
teta=0
p=0.025*teta+20
#p se arregla con un if luego
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)

esfRde=Rde/a*1000
esfRad=Rad/a*1000
esfRae=Rae/a*1000
esfRab=Rab/a*1000
esfRbe=Rbe/a*1000
esfRbc=esfRab
esfRce=Rce/a*1000
esfRde=abs(esfRde)
esfRad=abs(esfRad)
esfRae=abs(esfRae)
esfRab=abs(esfRab)
esfRbe=abs(esfRbe)
esfRbc=abs(esfRbc)
esfRce=abs(esfRce)

while esfRde>esf_ad or esfRad>esf_ad or esfRae>esf_ad or esfRab>esf_ad or esfRbe>esf_ad or esfRbc>esf_ad or esfRce>esf_ad:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    Dx=-4*p*cos(teta)
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rde=Dx
    Rad=0
    Rae=Ay/(sen(teta1))
    Rab=-Rae*cos(teta1)-Ax
    Rbe=0
    Rbc=Rab
    Rce=p*cos(teta)/sen(teta1)
    esfRde=abs(Rde)/a*1000
    esfRad=abs(Rad)/a*1000
    esfRae=abs(Rae)/a*1000
    esfRab=abs(Rab)/a*1000
    esfRbe=abs(Rbe)/a*1000
    esfRbc=abs(esfRab)
    esfRce=abs(Rce)/a*1000
print("Ángulo=",teta,"°")
# Out:
# Ángulo= 73.16270000130521 °

# %%
#(punto1)Derivadas de las reacciones de los elementos sabiendo qué: Cuando la derivada=0 el valor de la función es máximo
dp=0.025
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Dx
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
while abs(0-dDx)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    dDx=-4*(dp*cos(teta)-sen(teta)*p)
    Dx=-4*p*cos(teta)
m1=np.array([teta,p,Dx])
print(m1)
# Out:
# [ 7.10000000e-02  2.00000000e+01 -7.99999386e+01]

# %%
#((punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Ay
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dAy)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    dAy=-dp*cos(teta)-sen(teta)*p
    Ay=-p*cos(teta)
m2=np.array([teta,p,Ay])
print(m2)
# Out:
# [179.9386      24.25        24.24998608]

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Ax
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dAx)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    Dx=-4*p*cos(teta)
    dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
    Ax=-p*sen(teta)-Dx
m3=np.array([teta,p,Ax])
print(m3)
# Out:
# [166.0229      24.         -98.95448229]

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga Rde=Dx
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dDx)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    dDx=-4*(dp*cos(teta)-sen(teta)*p)
    Dx=-4*p*cos(teta)
    
Rde=Dx
dRde=dDx
m4=np.array([teta,p,Rde])
print(m4)
# Out:
# [ 7.10000000e-02  2.00000000e+01 -7.99999386e+01]

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Rad
Rad=0 #siempre será el mismo Rad
print("Cuálquier angulo con respectiva carga p, Rad=",Rad)
m5=np.array([0,0,0])
# Out:
# Cuálquier angulo con respectiva carga p, Rad= 0

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Rae
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dRae)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    Dx=-4*p*cos(teta)
    dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
    dRae=dAx/sen(teta1)
    Ay=-p*cos(teta)
    Rae=Ay/(sen(teta1))
m6=np.array([teta,p,Rae])
print(m6)
# Out:
# [166.0232      24.          52.07678557]

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Rab
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dRab)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    Dx=-4*p*cos(teta)
    dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
    dRae=dAx/sen(teta1)
    dRab=-dRae*cos(teta1)-dAx
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rae=Ay/(sen(teta1))
    Rab=-Rae*cos(teta1)-Ax
m7=np.array([teta,p,Rab])
print(m7)
# Out:
# [166.0233      24.          52.37556831]

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Rbe
Rbe=0 #siempre será el mismo Rbe
print("Cuálquier angulo con respectiva carga p, Rbe=",Rbe)
m8=np.array([0,0,0])
# Out:
# Cuálquier angulo con respectiva carga p, Rbe= 0

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Rbc=Rab
teta=0
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dRab)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    Dx=-4*p*cos(teta)
    dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
    dRae=dAx/sen(teta1)
    dRab=-dRae*cos(teta1)-dAx
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rae=Ay/(sen(teta1))
    Rab=-Rae*cos(teta1)-Ax
    
    
Rbc=Rab
dRbc=dRab
m9=np.array([teta,p,Rbc])
print(m9)
# Out:
# [166.0233      24.          52.37556831]

# %%
#(punto1)Ángulo que genera la fuerza interna máxima, con el valor de la carga, para Rce
dp=0.025
Dx=-4*p*cos(teta)
Ay=-p*cos(teta)
Ax=-p*sen(teta)-Dx
Rde=Dx
Rad=0
Rae=Ay/(sen(teta1))
Rab=-Rae*cos(teta1)-Ax
Rbe=0
Rbc=Rab
Rce=p*cos(teta)/sen(teta1)
dDx=-4*(dp*cos(teta)-sen(teta)*p)
dAy=-dp*cos(teta)-sen(teta)*p
dAx=-(dp*sen(teta)+cos(teta)*p)+4*(dp*cos(teta)-sen(teta)*p)
dRde=dDx
dRae=dAx/sen(teta1)
dRab=-dRae*cos(teta1)-dAx
dRbc=dRab
dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
while abs(0-dRce)>0.001:
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
    teta=teta+0.0001
    dRce=(dp*cos(teta)-sen(teta)*p)/sen(teta1)
    Rce=p*cos(teta)/sen(teta1)
m10=np.array([teta,p,Rce])
print(m10)
# Out:
# [180.0575      24.5        -54.78363786]

# %%
#(punto1)VALORES DE LAS REACCIONES EN TODOS LOS ELEMENTOS Y APOYOS
np.set_printoptions(suppress=True)
matriz=np.append([m1],[m2,m3,m4,m5,m6,m7,m8,m9,m10],axis=0)
print(matriz)
# Out:
# [[  0.071       20.         -79.99993858]
#  [179.9386      24.25        24.24998608]
#  [166.0229      24.         -98.95448229]
#  [  0.071       20.         -79.99993858]
#  [  0.           0.           0.        ]
#  [166.0232      24.          52.07678557]
#  [166.0233      24.          52.37556831]
#  [  0.           0.           0.        ]
#  [166.0233      24.          52.37556831]
#  [180.0575      24.5        -54.78363786]]

# %%
#Para el tercer punto CON LAS FUERZAS INTERNAS DE LOS ELEMENTOS
teta=0
for teta in range(0,190,10):
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
        x=(teta/1000)+2 #distancia desplazada de los nodos B,C y E
    teta2=math.degrees(math.atan(1/x))
    Dx=-(2+x)*p*cos(teta)
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rde=Dx
    Rad=0
    Rae=Ay/(sen(teta2))
    Rab=-Rae*cos(teta2)-Ax
    Rbe=0
    Rbc=Rab
    Rce=p*cos(teta)/sen(teta1)
    #print("Rde=",Rde)
    #print("Rad=",Rad)
    #print("Rae=",Rae)
    #print("Rab=",Rab)
    #print("Rbe=",Rbe)
    #print("Rbc=",Rbc)
    #print("Rce=",Rce)
    ARRAY=np.array([["Rde=",Rde,p],["Rad=",Rad,p],["Rae=",Rae,p],["Rab=",Rab,p],["Rbe=",Rbe,p],["Rbc=",Rbc,p],["Rce=",Rce,p]])
    print(ARRAY)
# Out:
# [['Rde=' '-80.0' '20.0']
#  ['Rad=' '0' '20.0']
#  ['Rae=' '-44.721359549995796' '20.0']
#  ['Rab=' '-40.0' '20.0']
#  ['Rbe=' '0' '20.0']
#  ['Rbc=' '-40.0' '20.0']
#  ['Rce=' '44.721359549995796' '20.0']]
# [['Rde=' '-79.96885156397383' '20.25']
#  ['Rad=' '0' '20.25']
#  ['Rae=' '-44.77092457325445' '20.25']
#  ['Rab=' '-36.3683383992391' '20.25']
#  ['Rbe=' '0' '20.25']
#  ['Rbc=' '-36.3683383992391' '20.25']
#  ['Rce=' '44.592465880208444' '20.25']]
# [['Rde=' '-77.44006887896671' '20.5']
#  ['Rad=' '0' '20.5']
#  ['Rae=' '-43.419881231714015' '20.5']
#  ['Rab=' '-31.515984514046032' '20.5']
#  ['Rbe=' '0' '20.5']
#  ['Rbc=' '-31.515984514046032' '20.5']
#  ['Rce=' '43.07493984966057' '20.5']]
# [['Rde=' '-72.41920932796421' '20.75']
#  ['Rad=' '0' '20.75']
#  ['Rae=' '-40.66510334042568' '20.75']
#  ['Rab=' '-25.5650542570542' '20.75']
#  ['Rbe=' '0' '20.75']
#  ['Rbc=' '-25.5650542570542' '20.75']
#  ['Rce=' '40.182202216901956' '20.75']]
# ...

# %%
#PUNTO NÚMERO 4
teta=0
for teta in range(0,190,10):
    if math.floor(teta)%10==0:
        p=0.025*math.floor(teta)+20
        x=(teta/1000)+2 #distancia desplazada de los nodos B,C y E
    teta2=math.degrees(math.atan(1/x))
    Dx=-(2+x)*p*cos(teta)
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rde=Dx
    Rad=0
    Rae=Ay/(sen(teta2))
    Rab=-Rae*cos(teta2)-Ax
    Rbe=0
    Rbc=Rab
    Rce=p*cos(teta)/sen(teta1)
    print("Para cuando el ángulo vale",teta,"°")
    
    plt.rcParams["figure.figsize"]=(6,4)
    plt.style.use('seaborn-whitegrid')
    AB=x
    H=1
    BC=2
    AC=BC+x
    xeje=np.array([
        0,AB,AC,AB,0,0,AB,AB
    ])
    yeje=np.array([
    H,H,H,0,0,H,0,H
    ])
    plt.plot(xeje,yeje)
    plt.text( AB,0, str(round(AB,3)))
    plt.text(AB,H,str(round(AB,3)))
    plt.text(AC,H,str(round(AC,3)))
    plt.title(f'Desplazamientos de nodos B,C,E cuando el aumento de la posición es {round(x-2,3)}')
    plt.show()
# Out:
# Para cuando el ángulo vale 0 °
# Para cuando el ángulo vale 10 °
# Para cuando el ángulo vale 20 °
# Para cuando el ángulo vale 30 °
# Para cuando el ángulo vale 40 °
# Para cuando el ángulo vale 50 °
# Para cuando el ángulo vale 60 °
# Para cuando el ángulo vale 70 °
# Para cuando el ángulo vale 80 °
# Para cuando el ángulo vale 90 °
# Para cuando el ángulo vale 100 °
# Para cuando el ángulo vale 110 °
# Para cuando el ángulo vale 120 °
# Para cuando el ángulo vale 130 °
# Para cuando el ángulo vale 140 °
# Para cuando el ángulo vale 150 °
# Para cuando el ángulo vale 160 °
# Para cuando el ángulo vale 170 °
# Para cuando el ángulo vale 180 °

# %%
#punto5
teta=80
p=0.025*math.floor(teta)+20
X=[]
ESFRde=[]
ESFRad=[]
ESFRae=[]
ESFRab=[]
ESFRbe=[]
ESFRbc=[]
ESFRce=[]
for tetax in range(0,190,10):
    if math.floor(tetax)%10==0:
        x=(tetax/1000)+2 #distancia desplazada de los nodos B,C y E
    teta2=math.degrees(math.atan(1/x))
    Dx=-(2+x)*p*cos(teta)
    Ay=-p*cos(teta)
    Ax=-p*sen(teta)-Dx
    Rde=Dx
    Rad=0
    Rae=Ay/(sen(teta2))
    Rab=-Rae*cos(teta2)-Ax
    Rbe=0
    Rbc=Rab
    Rce=p*cos(teta)/sen(teta1)
    esfRde=Rde/a*1000
    esfRad=Rad/a*1000
    esfRae=Rae/a*1000
    esfRab=Rab/a*1000
    esfRbe=Rbe/a*1000
    esfRbc=esfRab
    esfRce=Rce/a*1000
    X+=[x]
    ESFRde+=[esfRde]
    ESFRad+=[esfRad]
    ESFRae+=[esfRae]
    ESFRab+=[esfRab]
    ESFRbe+=[esfRbe]
    ESFRbc+=[esfRbc]
    ESFRce+=[esfRce]

plt.rcParams["figure.figsize"]=(8,30)
plt.style.use('seaborn-whitegrid')
fig, axes=plt.subplots(nrows=7,ncols=1,sharex=True)
axes[0].plot(X,ESFRde)
axes[1].plot(X,ESFRad)
axes[2].plot(X,ESFRae)
axes[3].plot(X,ESFRab)
axes[4].plot(X,ESFRbe)
axes[5].plot(X,ESFRbc)
axes[6].plot(X,ESFRce)

axes[0].set_title("Esfuerzo ESFRde")
axes[1].set_title("Esfuerzo ESFRad")
axes[2].set_title("Esfuerzo ESFRae")
axes[3].set_title("Esfuerzo ESFRab")
axes[4].set_title("Esfuerzo ESFRbe")
axes[5].set_title("Esfuerzo ESFRbc")
axes[6].set_title("Esfuerzo ESFRce")
for ax in axes.flat:
    ax.set(xlabel='Desplazamiento [m]', ylabel='Esfuerzo [MPa]')
