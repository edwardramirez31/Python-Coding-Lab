# %%
import numpy as np

# %%
a = np.arange(10).reshape(2,-1)

# %%
b = np.repeat(1,10).reshape(2,-1)

# %%
#El comando hstack permite directamente apilar 2 matrices de forma horizontal

# %%
np.hstack([a,b])
# Out:
# array([[0, 1, 2, 3, 4, 1, 1, 1, 1, 1],
#        [5, 6, 7, 8, 9, 1, 1, 1, 1, 1]])
